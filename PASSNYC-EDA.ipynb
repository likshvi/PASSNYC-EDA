# %% [markdown]
# **This the the Exploratory data analysis of data PASSNYC from kaggle which contains two CSV files.**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1= pd.read_csv("C:\\Users\\Likshvit\\Desktop\\datafiles\\PASSNYC\\2016 School Explorer.csv")
df1.shape
# Out:
# (1272, 161)

# %%
df2= pd.read_csv("C:\\Users\\Likshvit\\Desktop\\datafiles\\PASSNYC\\D5 SHSAT Registrations and Testers.csv")
df2.shape
# Out:
# (140, 7)

# %% [markdown]
# <font size=3>Taking a look on the data</font>

# %%
df1.head()
# Out:
#   Adjusted Grade New? Other Location Code in LCGMS  \
# 0            NaN  NaN                          NaN
# 1            NaN  NaN                          NaN
# 2            NaN  NaN                          NaN
# 3            NaN  NaN                          NaN
# 4            NaN  NaN                          NaN
#
#                       School Name      SED Code Location Code  District  \
# 0       P.S. 015 ROBERTO CLEMENTE  310100010015        01M015         1
# 1             P.S. 019 ASHER LEVY  310100010019        01M019         1
# 2            P.S. 020 ANNA SILVER  310100010020        01M020         1
# 3  P.S. 034 FRANKLIN D. ROOSEVELT  310100010034        01M034         1
# 4       THE STAR ACADEMY - P.S.63  310100010063        01M063         1
#
#     Latitude  Longitude                    Address (Full)  \
# 0  40.721834 -73.978766   333 E 4TH ST NEW YORK, NY 10009
# 1  40.729892 -73.984231    185 1ST AVE NEW YORK, NY 10003
# ...

# %%
df2.head()
# Out:
#       DBN               School name  Year of SHST  Grade level  \
# 0  05M046    P.S. 046 Arthur Tappan          2013            8
# 1  05M046    P.S. 046 Arthur Tappan          2014            8
# 2  05M046    P.S. 046 Arthur Tappan          2015            8
# 3  05M046    P.S. 046 Arthur Tappan          2016            8
# 4  05M123  P.S. 123 Mahalia Jackson          2013            8
#
#    Enrollment on 10/31  Number of students who registered for the SHSAT  \
# 0                   91                                               31
# 1                   95                                               26
# 2                   73                                               21
# 3                   56                                               20
# 4                   62                                               31
#
#    Number of students who took the SHSAT
# 0                                     14
# 1                                      7
# ...

# %% [markdown]
# <font size=3>Finding the null values in data</font>

# %%
df1.isnull().sum().sort_values(ascending=True)
# Out:
# Grade 4 Math 4s - Economically Disadvantaged             0
# Grade 6 ELA 4s - All Students                            0
# Grade 6 ELA 4s - American Indian or Alaska Native        0
# Grade 6 ELA 4s - Black or African American               0
# Grade 6 ELA 4s - Hispanic or Latino                      0
# Grade 6 ELA 4s - Asian or Pacific Islander               0
# Grade 6 ELA 4s - White                                   0
# Grade 6 ELA 4s - Multiracial                             0
# Grade 6 ELA - All Students Tested                        0
# Grade 6 ELA 4s - Limited English Proficient              0
# Grade 6 Math - All Students Tested                       0
# Grade 6 Math 4s - All Students                           0
# Grade 6 Math 4s - American Indian or Alaska Native       0
# Grade 6 Math 4s - Black or African American              0
# Grade 6 Math 4s - Hispanic or Latino                     0
# Grade 6 Math 4s - Asian or Pacific Islander              0
# ...

# %%
df1.describe().sort_values(ascending=True,by='Economic Need Index')
# Out:
#            SED Code    District     Latitude    Longitude           Zip  \
# min    3.075000e+11     1.00000    40.507803   -74.244025  10001.000000
# std    1.222022e+10     9.24527     0.086602     0.080576    529.588875
# 25%    3.208752e+11     9.00000    40.669499   -73.957057  10452.000000
# mean   3.286698e+11    16.13522    40.734537   -73.918347  10815.720912
# 50%    3.315004e+11    15.00000    40.722995   -73.920571  11203.000000
# 75%    3.424000e+11    24.00000    40.815632   -73.879264  11232.000000
# max    3.531009e+11    32.00000    40.903455   -73.708920  11694.000000
# count  1.272000e+03  1272.00000  1272.000000  1272.000000   1272.000000
#
#        Economic Need Index  Average ELA Proficiency  Average Math Proficiency  \
# min               0.049000                 1.810000                  1.830000
# std               0.210959                 0.363589                  0.470470
# 25%               0.550000                 2.250000                  2.300000
# ...

# %% [markdown]
# <font size=3>Checking basic descriptive statistics</font>

# %%
df2.describe()
# Out:
#        Year of SHST  Grade level  Enrollment on 10/31  \
# count    140.000000   140.000000           140.000000
# mean    2014.542857     8.392857            91.971429
# std        1.121224     0.490139            47.494027
# min     2013.000000     8.000000            17.000000
# 25%     2014.000000     8.000000            62.750000
# 50%     2015.000000     8.000000            86.000000
# 75%     2016.000000     9.000000           113.000000
# max     2016.000000     9.000000           344.000000
#
#        Number of students who registered for the SHSAT  \
# count                                       140.000000
# mean                                         19.071429
# std                                          23.280165
# min                                           0.000000
# 25%                                           2.000000
# 50%                                          12.000000
# 75%                                          26.000000
# ...

# %% [markdown]
# <font size=3>Finding the distribution of data among itself.</font>

# %%
df2.loc[df2['Number of students who took the SHSAT']].groupby("Grade level").size()
# Out:
# Grade level
# 8    123
# 9     17
# dtype: int64

# %%
df1['City'].describe()
# Out:
# count         1272
# unique          45
# top       BROOKLYN
# freq           411
# Name: City, dtype: object

# %%
g = sns.heatmap(df2[["Number of students who registered for the SHSAT","Number of students who took the SHSAT"]].corr(),annot=True)

# %%
#df1[['City','Economic Need Index']]
# df3=df1.sort_values(by=['Economic Need Index'],ascending=False)
# df3=df3.iloc[:500,]
# # df3.head()

#print(df1.dtypes.tolist())
df1_num=df1.select_dtypes(include=['int64','float64'])
df1_num.shape
# Out:
# (1272, 128)

# %%
df2_num=df2.select_dtypes(include=['int64','float64'])
df2_num.shape
df2_num_corr=df2_num.corr()['Number of students who took the SHSAT'][:-1]
golden_features_list = df2_num_corr[abs(df2_num_corr) > 0.5]
golden_features_list
sns.pairplot(df2_num, height=5, kind="reg",vars=["Number of students who registered for the SHSAT","Number of students who took the SHSAT"])
sns.pairplot(df2_num, height=5, vars=["Grade level","Number of students who took the SHSAT"])

# %%
#community=df1[df1["Community School?"]=='Yes'].groupby('City').count()

# %% [markdown]
# <font size=4>More to be added</font>
